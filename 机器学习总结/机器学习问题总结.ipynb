# %% [markdown]
# # 生成模型、判别模型

# %% [markdown]
# 生成模型，估计联合概率P(x,y)
# 判别模型，估计条件概率P(y|x)
# [知乎：二者之间的差别](https://www.zhihu.com/question/20446337)

# %% [markdown]
# ## 生成模型优缺点

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 判别模型优缺点

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 常用模型分类
# 生成模型：贝叶斯估计，LDA(线性判别准则Fisher准则，有监督学习)、高斯混合模型(EM算法运用)
# 判别模型：逻辑回归（只计算后验概率，怎么做到的）
# [LDA](https://www.cnblogs.com/zhangchaoyang/articles/2644095.html)

# %% [markdown]
# # 贝叶斯估计，极大似然估计，极大后验估计

# %% [markdown]
# [三种参数估计方法](http://blog.csdn.net/yangliuy/article/details/8296481)
